# %%
import pandas as pd
import numpy as np
import math
import glob
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from multiprocessing import Pool
seed = 42

# %%
with Pool(50) as p:
    samples = pd.concat(p.map(pd.read_csv, glob.glob('./outputs/det/*.csv')))
samples = samples.reset_index(drop=True)

# %%
samples = samples.drop(samples[samples.EIR == -1].index).reset_index(drop=True)

# %%
output_columns = [f'prev_{i}' for i in range(1, 366)]
outputs = samples[output_columns]
features = samples.drop(output_columns + ['init_EIR'], 1)
n_features = len(features.columns)
n_outputs = len(outputs.columns)
# Out:
# /tmp/ipykernel_24762/3418533024.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   features = samples.drop(output_columns + ['init_EIR'], 1)

# %%
idx_train, idx_test = train_test_split(
    np.arange(len(outputs)), #np.arange(100000),
    test_size=0.2,
    random_state=seed
)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, layers, Model
# Out:
# 2022-11-09 15:17:51.777266: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-09 15:17:51.946594: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
X_train = features.iloc[idx_train]
y_train = outputs.iloc[idx_train].to_numpy()[:, :, np.newaxis]
X_test = features.iloc[idx_test]
y_test = outputs.iloc[idx_test].to_numpy()[:, :, np.newaxis]

scaler = layers.Normalization()
scaler.adapt(X_train.to_numpy())
# Out:
# 2022-11-09 15:17:53.714511: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-09 15:17:57.711233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22337 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:27:00.0, compute capability: 8.6
# 2022-11-09 15:17:57.713712: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22337 MB memory:  -> device: 1, name: NVIDIA RTX A5000, pci bus id: 0000:28:00.0, compute capability: 8.6
# 2022-11-09 15:17:57.715910: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 22337 MB memory:  -> device: 2, name: NVIDIA RTX A5000, pci bus id: 0000:43:00.0, compute capability: 8.6
# 2022-11-09 15:17:57.718094: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 22337 MB memory:  -> device: 3, name: NVIDIA RTX A5000, pci bus id: 0000:44:00.0, compute capability: 8.6
# 2022-11-09 15:17:57.720259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 22337 MB memory:  -> device: 4, name: NVIDIA RTX A5000, pci bus id: 0000:a3:00.0, compute capability: 8.6
# 2022-11-09 15:17:57.722423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 22337 MB memory:  -> device: 5, name: NVIDIA RTX A5000, pci bus id: 0000:a4:00.0, compute capability: 8.6
# 2022-11-09 15:17:57.724585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 22337 MB memory:  -> device: 6, name: NVIDIA RTX A5000, pci bus id: 0000:c3:00.0, compute capability: 8.6
# 2022-11-09 15:17:57.726724: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 22337 MB memory:  -> device: 7, name: NVIDIA RTX A5000, pci bus id: 0000:c4:00.0, compute capability: 8.6

# %%
def create_sequence_model(
    optimiser='adam',
    n_hidden=2,
    units=128,
    loss='log_cosh',
    hidden_activation='relu',
    hidden_initialiser='he_normal',
    output_activation='linear',
    output_initialiser='glorot_normal',
    output_units=y_train.shape[2]
):
    input_layer = layers.Input(shape=(n_features,), dtype='float32')
    input_encoding = scaler(input_layer)
    for i in range(n_hidden):
        input_encoding = layers.Dense(
            units,
            activation=hidden_activation,
            kernel_initializer=hidden_initialiser
        )(input_encoding)
    output = tf.repeat(input_encoding[:, tf.newaxis, :], 365, 1)
    for i in range(n_hidden):
        output = layers.LSTM(units, return_sequences=True)(output)
    output = layers.TimeDistributed(layers.Dense(output_units, activation=output_activation, kernel_initializer=output_initialiser))(output)
    model = Model(inputs = [input_layer], outputs = [output])
    model.compile(loss=loss, optimizer=optimiser, metrics='mse')
    return model

# %%
model = create_sequence_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 31)]              0
#
#  normalization (Normalizatio  (None, 31)               63
#  n)
#
#  dense (Dense)               (None, 128)               4096
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  tf.__operators__.getitem (S  (None, 1, 128)           0
#  licingOpLambda)
#
#  tf.repeat (TFOpLambda)      (None, 365, 128)          0
#
#  lstm (LSTM)                 (None, 365, 128)          131584
#
#  lstm_1 (LSTM)               (None, 365, 128)          131584
#
#  time_distributed (TimeDistr  (None, 365, 1)           129
#  ibuted)
#
# =================================================================
# Total params: 283,968
# Trainable params: 283,905
# Non-trainable params: 63
# _________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size=100, epochs=100)
# Out:
# Epoch 1/100
# 2022-11-09 15:18:14.116174: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-11-09 15:18:14.677767: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 463/463 [==============================] - 29s 55ms/step - loss: 0.0047 - mse: 0.0096
# Epoch 2/100
# 463/463 [==============================] - 25s 55ms/step - loss: 0.0025 - mse: 0.0050
# Epoch 3/100
# 463/463 [==============================] - 25s 54ms/step - loss: 0.0021 - mse: 0.0043
# Epoch 4/100
# 463/463 [==============================] - 25s 55ms/step - loss: 0.0020 - mse: 0.0039
# Epoch 5/100
# 463/463 [==============================] - 26s 55ms/step - loss: 0.0018 - mse: 0.0037
# Epoch 6/100
# 463/463 [==============================] - 25s 55ms/step - loss: 0.0018 - mse: 0.0036
# Epoch 7/100
# 463/463 [==============================] - 26s 56ms/step - loss: 0.0017 - mse: 0.0035
# Epoch 8/100
# 463/463 [==============================] - 26s 55ms/step - loss: 0.0017 - mse: 0.0034
# Epoch 9/100
# 463/463 [==============================] - 25s 54ms/step - loss: 0.0017 - mse: 0.0034
# Epoch 10/100
# 463/463 [==============================] - 25s 54ms/step - loss: 0.0017 - mse: 0.0033
# Epoch 11/100
# 463/463 [==============================] - 25s 54ms/step - loss: 0.0016 - mse: 0.0033
# Epoch 12/100
# 463/463 [==============================] - 25s 55ms/step - loss: 0.0016 - mse: 0.0032
# Epoch 13/100
# 463/463 [==============================] - 25s 55ms/step - loss: 0.0016 - mse: 0.0032
# Epoch 14/100
# 463/463 [==============================] - 26s 55ms/step - loss: 0.0015 - mse: 0.0030
# Epoch 15/100
# 463/463 [==============================] - 25s 55ms/step - loss: 0.0013 - mse: 0.0026
# Epoch 16/100
# 463/463 [==============================] - 25s 54ms/step - loss: 0.0011 - mse: 0.0022
# Epoch 17/100
# 463/463 [==============================] - 25s 54ms/step - loss: 9.1314e-04 - mse: 0.0018
# Epoch 18/100
# 463/463 [==============================] - 25s 55ms/step - loss: 7.5659e-04 - mse: 0.0015
# Epoch 19/100
# 463/463 [==============================] - 25s 55ms/step - loss: 6.1827e-04 - mse: 0.0012
# Epoch 20/100
# 463/463 [==============================] - 25s 55ms/step - loss: 5.3075e-04 - mse: 0.0011
# Epoch 21/100
# 463/463 [==============================] - 26s 56ms/step - loss: 4.4586e-04 - mse: 8.9290e-04
# Epoch 22/100
# 463/463 [==============================] - 25s 55ms/step - loss: 3.8527e-04 - mse: 7.7145e-04
# Epoch 23/100
# 463/463 [==============================] - 25s 54ms/step - loss: 3.5400e-04 - mse: 7.0881e-04
# Epoch 24/100
# 463/463 [==============================] - 26s 55ms/step - loss: 3.2449e-04 - mse: 6.4974e-04
# Epoch 25/100
# 463/463 [==============================] - 25s 55ms/step - loss: 2.8235e-04 - mse: 5.6523e-04
# Epoch 26/100
# 463/463 [==============================] - 26s 55ms/step - loss: 2.9803e-04 - mse: 5.9683e-04
# Epoch 27/100
# 463/463 [==============================] - 26s 56ms/step - loss: 3.3528e-04 - mse: 6.7172e-04
# Epoch 28/100
# 463/463 [==============================] - 26s 56ms/step - loss: 2.7253e-04 - mse: 5.4566e-04
# Epoch 29/100
# 463/463 [==============================] - 25s 55ms/step - loss: 2.9392e-04 - mse: 5.8868e-04
# Epoch 30/100
# 463/463 [==============================] - 25s 54ms/step - loss: 2.8754e-04 - mse: 5.7590e-04
# Epoch 31/100
# 463/463 [==============================] - 25s 54ms/step - loss: 2.4603e-04 - mse: 4.9267e-04
# Epoch 32/100
# 463/463 [==============================] - 25s 54ms/step - loss: 1.9962e-04 - mse: 3.9952e-04
# Epoch 33/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.8658e-04 - mse: 3.7338e-04
# Epoch 34/100
# 463/463 [==============================] - 25s 54ms/step - loss: 1.9286e-04 - mse: 3.8601e-04
# Epoch 35/100
# 463/463 [==============================] - 26s 55ms/step - loss: 1.8841e-04 - mse: 3.7718e-04
# Epoch 36/100
# 463/463 [==============================] - 25s 54ms/step - loss: 2.6283e-04 - mse: 5.2651e-04
# Epoch 37/100
# 463/463 [==============================] - 25s 54ms/step - loss: 2.0425e-04 - mse: 4.0894e-04
# Epoch 38/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.6736e-04 - mse: 3.3493e-04
# Epoch 39/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.5465e-04 - mse: 3.0949e-04
# Epoch 40/100
# 463/463 [==============================] - 25s 54ms/step - loss: 1.6018e-04 - mse: 3.2060e-04
# Epoch 41/100
# 463/463 [==============================] - 26s 55ms/step - loss: 1.4404e-04 - mse: 2.8822e-04
# Epoch 42/100
# 463/463 [==============================] - 25s 55ms/step - loss: 2.0236e-04 - mse: 4.0537e-04
# Epoch 43/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.5200e-04 - mse: 3.0422e-04
# Epoch 44/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.3493e-04 - mse: 2.7001e-04
# Epoch 45/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.7833e-04 - mse: 3.5711e-04
# Epoch 46/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.6693e-04 - mse: 3.3418e-04
# Epoch 47/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.5155e-04 - mse: 3.0334e-04
# Epoch 48/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.2327e-04 - mse: 2.4671e-04
# Epoch 49/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.3944e-04 - mse: 2.7911e-04
# Epoch 50/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.3092e-04 - mse: 2.6208e-04
# Epoch 51/100
# 463/463 [==============================] - 25s 54ms/step - loss: 1.6247e-04 - mse: 3.2532e-04
# Epoch 52/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.1493e-04 - mse: 2.3000e-04
# Epoch 53/100
# 463/463 [==============================] - 26s 56ms/step - loss: 1.1470e-04 - mse: 2.2950e-04
# Epoch 54/100
# 463/463 [==============================] - 26s 56ms/step - loss: 1.1932e-04 - mse: 2.3884e-04
# Epoch 55/100
# 463/463 [==============================] - 26s 57ms/step - loss: 1.2114e-04 - mse: 2.4251e-04
# Epoch 56/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.1401e-04 - mse: 2.2820e-04
# Epoch 57/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.0360e-04 - mse: 2.0728e-04
# Epoch 58/100
# 463/463 [==============================] - 26s 55ms/step - loss: 9.5185e-05 - mse: 1.9043e-04
# Epoch 59/100
# 463/463 [==============================] - 25s 55ms/step - loss: 9.1019e-05 - mse: 1.8211e-04
# Epoch 60/100
# 463/463 [==============================] - 26s 56ms/step - loss: 1.1132e-04 - mse: 2.2284e-04
# Epoch 61/100
# 463/463 [==============================] - 26s 56ms/step - loss: 1.1612e-04 - mse: 2.3248e-04
# Epoch 62/100
# 463/463 [==============================] - 25s 55ms/step - loss: 9.8227e-05 - mse: 1.9657e-04
# Epoch 63/100
# 463/463 [==============================] - 25s 54ms/step - loss: 8.8694e-05 - mse: 1.7744e-04
# Epoch 64/100
# 463/463 [==============================] - 25s 54ms/step - loss: 8.3699e-05 - mse: 1.6748e-04
# Epoch 65/100
# 463/463 [==============================] - 25s 54ms/step - loss: 8.8996e-05 - mse: 1.7809e-04
# Epoch 66/100
# 463/463 [==============================] - 25s 55ms/step - loss: 9.8277e-05 - mse: 1.9671e-04
# Epoch 67/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.1619e-04 - mse: 2.3270e-04
# Epoch 68/100
# 463/463 [==============================] - 26s 56ms/step - loss: 9.4893e-05 - mse: 1.8994e-04
# Epoch 69/100
# 463/463 [==============================] - 26s 55ms/step - loss: 8.0784e-05 - mse: 1.6162e-04
# Epoch 70/100
# 463/463 [==============================] - 25s 54ms/step - loss: 1.1276e-04 - mse: 2.2584e-04
# Epoch 71/100
# 463/463 [==============================] - 25s 54ms/step - loss: 1.7996e-04 - mse: 3.6050e-04
# Epoch 72/100
# 463/463 [==============================] - 26s 55ms/step - loss: 1.1494e-04 - mse: 2.3011e-04
# Epoch 73/100
# 463/463 [==============================] - 26s 55ms/step - loss: 9.5388e-05 - mse: 1.9091e-04
# Epoch 74/100
# 463/463 [==============================] - 26s 55ms/step - loss: 8.6269e-05 - mse: 1.7263e-04
# Epoch 75/100
# 463/463 [==============================] - 25s 54ms/step - loss: 1.5798e-04 - mse: 3.1646e-04
# Epoch 76/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.1091e-04 - mse: 2.2207e-04
# Epoch 77/100
# 463/463 [==============================] - 26s 55ms/step - loss: 9.4277e-05 - mse: 1.8872e-04
# Epoch 78/100
# 463/463 [==============================] - 25s 55ms/step - loss: 9.4884e-05 - mse: 1.8990e-04
# Epoch 79/100
# 463/463 [==============================] - 25s 54ms/step - loss: 8.4687e-05 - mse: 1.6949e-04
# Epoch 80/100
# 463/463 [==============================] - 26s 55ms/step - loss: 9.0946e-05 - mse: 1.8205e-04
# Epoch 81/100
# 463/463 [==============================] - 26s 55ms/step - loss: 9.1681e-05 - mse: 1.8354e-04
# Epoch 82/100
# 463/463 [==============================] - 25s 54ms/step - loss: 9.0146e-05 - mse: 1.8045e-04
# Epoch 83/100
# 463/463 [==============================] - 25s 54ms/step - loss: 7.5245e-05 - mse: 1.5059e-04
# Epoch 84/100
# 463/463 [==============================] - 26s 56ms/step - loss: 7.3227e-05 - mse: 1.4652e-04
# Epoch 85/100
# 463/463 [==============================] - 26s 55ms/step - loss: 6.9042e-05 - mse: 1.3815e-04
# Epoch 86/100
# 463/463 [==============================] - 25s 55ms/step - loss: 7.2715e-05 - mse: 1.4553e-04
# Epoch 87/100
# 463/463 [==============================] - 25s 54ms/step - loss: 7.2498e-05 - mse: 1.4507e-04
# Epoch 88/100
# 463/463 [==============================] - 25s 55ms/step - loss: 6.9746e-05 - mse: 1.3956e-04
# Epoch 89/100
# 463/463 [==============================] - 25s 55ms/step - loss: 6.9205e-05 - mse: 1.3845e-04
# Epoch 90/100
# 463/463 [==============================] - 25s 55ms/step - loss: 7.9709e-05 - mse: 1.5955e-04
# Epoch 91/100
# 463/463 [==============================] - 25s 55ms/step - loss: 7.6199e-05 - mse: 1.5250e-04
# Epoch 92/100
# 463/463 [==============================] - 25s 55ms/step - loss: 6.8176e-05 - mse: 1.3641e-04
# Epoch 93/100
# 463/463 [==============================] - 25s 54ms/step - loss: 6.4746e-05 - mse: 1.2954e-04
# Epoch 94/100
# 463/463 [==============================] - 26s 55ms/step - loss: 6.8506e-05 - mse: 1.3711e-04
# Epoch 95/100
# 463/463 [==============================] - 25s 54ms/step - loss: 1.2847e-04 - mse: 2.5737e-04
# Epoch 96/100
# 463/463 [==============================] - 25s 54ms/step - loss: 8.5147e-05 - mse: 1.7045e-04
# Epoch 97/100
# 463/463 [==============================] - 25s 55ms/step - loss: 1.1389e-04 - mse: 2.2822e-04
# Epoch 98/100
# 463/463 [==============================] - 25s 55ms/step - loss: 7.0801e-05 - mse: 1.4170e-04
# Epoch 99/100
# 463/463 [==============================] - 26s 55ms/step - loss: 7.5755e-05 - mse: 1.5163e-04
# Epoch 100/100
# 463/463 [==============================] - 25s 55ms/step - loss: 6.4955e-05 - mse: 1.2997e-04

# %%
y_hat = model.predict(X_test)
# Out:
# 362/362 [==============================] - 7s 18ms/step

# %%
np.abs(np.mean(y_hat, axis=1) - np.mean(y_test, axis=1))[:,0]
# Out:
# array([0.00934085, 0.00481503, 0.01574441, ..., 0.00166701, 0.00362029,
#        0.0252892 ])

# %%
np.abs(y_hat.flatten() - y_test.flatten())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 np.abs(y_hat.flatten() - y_test.flatten())
#
# NameError: name 'np' is not defined

# %%
plt.boxplot([
    np.abs(y_hat.flatten() - y_test.flatten()),
    np.abs(np.mean(y_hat, axis=1) - np.mean(y_test, axis=1))[:,0]
])
plt.xticks(labels=['daily', 'yearly'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [29], line 5
#       1 plt.boxplot([
#       2     np.abs(y_hat.flatten() - y_test.flatten()),
#       3     np.abs(np.mean(y_hat, axis=1) - np.mean(y_test, axis=1))[:,0]
#       4 ])
# ----> 5 plt.xticks(labels=['daily', 'yearly'])
#
# TypeError: 'list' object is not callable

# %%
plt.scatter(y_hat.flatten(), y_test.flatten(), s=0.1)
plt.plot(np.linspace(0, 0.9), np.linspace(0, 0.9), linestyle=':', color='orange')
plt.xlabel('pred')
plt.ylabel('true')
# Out:
# Text(0, 0.5, 'true')

# %%
plt.plot(range(365), y_hat[3,:,0])
plt.plot(range(365), y_test[3,:,0])

# %%
plt.scatter(np.mean(y_hat, axis=1), np.mean(y_test, axis=1), s=0.1)
plt.plot(np.linspace(0, 0.9), np.linspace(0, 0.9), linestyle=':', color='orange')
plt.xlabel('pred')
plt.ylabel('true')
# Out:
# Text(0, 0.5, 'true')

# %%
import keras_tuner as kt

# %%
def bulid_hypermodel(hp):
    return create_model(
        n_hidden = hp.Int("n_hidden", min_value=1, max_value=5, step=1),
        units = hp.Int("units", min_value=32, max_value=512, step=32),
        dropout = hp.Float("dropout", min_value=0., max_value=.2, step=.01),
        loss = hp.Choice("loss", ['mse', 'log_cosh']),
        hidden_activation = hp.Choice("hidden_activation", ['relu', 'elu']),
        output_activation = hp.Choice("output_activation", ['linear', 'softmax'])
    )

# %%
tuner = kt.Hyperband(
    hypermodel=bulid_hypermodel,
    objective="val_mse",
    max_epochs=100,
    seed=42,
    overwrite=True,
    directory="hyperparameters",
    project_name="det",
)

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 6
# n_hidden (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 5, 'step': 1, 'sampling': None}
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# dropout (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.2, 'step': 0.01, 'sampling': None}
# loss (Choice)
# {'default': 'mse', 'conditions': [], 'values': ['mse', 'log_cosh'], 'ordered': False}
# hidden_activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'elu'], 'ordered': False}
# output_activation (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'softmax'], 'ordered': False}

# %%
X_hyp_train, X_hyp_val, y_hyp_train, y_hyp_val = train_test_split(
    X_train,
    y_train,
    test_size=0.2,
    random_state=seed
)

# %%
tuner.search(
    X_hyp_train,
    y_hyp_train,
    validation_data=(X_hyp_val, y_hyp_val),
    callbacks=[tf.keras.callbacks.EarlyStopping("mse", min_delta=1e-10, patience=5)]
)
# Out:
# Trial 230 Complete [00h 02m 17s]
# val_mse: 0.00022005359642207623
#
# Best val_mse So Far: 9.33476330828853e-05
# Total elapsed time: 02h 25m 44s
#
# Search: Running Trial #231
#
# Value             |Best Value So Far |Hyperparameter
# 4                 |4                 |n_hidden
# 192               |96                |units
# 0.02              |0                 |dropout
# mse               |mse               |loss
# elu               |elu               |hidden_activation
# linear            |linear            |output_activation
# 34                |100               |tuner/epochs
# 12                |34                |tuner/initial_epoch
# 2                 |4                 |tuner/bracket
# 1                 |4                 |tuner/round
# 0225              |0144              |tuner/trial_id
#
# Epoch 13/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 14/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 15/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 9.4117e-04 - val_mse: 9.4117e-04
# Epoch 16/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 6.9665e-04 - val_mse: 6.9665e-04
# Epoch 17/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 6.0813e-04 - val_mse: 6.0813e-04
# Epoch 18/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 9.1305e-04 - mse: 9.1305e-04 - val_loss: 5.7177e-04 - val_mse: 5.7177e-04
# Epoch 19/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 8.1329e-04 - mse: 8.1329e-04 - val_loss: 5.4775e-04 - val_mse: 5.4775e-04
# Epoch 20/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 7.4924e-04 - mse: 7.4924e-04 - val_loss: 5.9009e-04 - val_mse: 5.9009e-04
# Epoch 21/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 7.0331e-04 - mse: 7.0331e-04 - val_loss: 3.6985e-04 - val_mse: 3.6985e-04
# Epoch 22/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 6.5834e-04 - mse: 6.5834e-04 - val_loss: 3.8562e-04 - val_mse: 3.8562e-04
# Epoch 23/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 6.0862e-04 - mse: 6.0862e-04 - val_loss: 4.3958e-04 - val_mse: 4.3958e-04
# Epoch 24/34
#  804/2000 [===========>..................] - ETA: 3s - loss: 5.8519e-04 - mse: 5.8519e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 tuner.search(
#       2     X_hyp_train,
#       3     y_hyp_train,
#       4     validation_data=(X_hyp_val, y_hyp_val),
#       5     callbacks=[tf.keras.callbacks.EarlyStopping("mse", min_delta=1e-10, patience=5)]
#       6 )
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras_tuner/engine/base_tuner.py:183, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     180     continue
#     182 self.on_trial_begin(trial)
# --> 183 results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     184 # `results` is None indicates user updated oracle in `run_trial()`.
#     185 if results is None:
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras_tuner/tuners/hyperband.py:384, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     382     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     383     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 384 return super(Hyperband, self).run_trial(trial, *fit_args, **fit_kwargs)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras_tuner/engine/tuner.py:295, in Tuner.run_trial(self, trial, *args, **kwargs)
#     293     callbacks.append(model_checkpoint)
#     294     copied_kwargs["callbacks"] = callbacks
# --> 295     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     297     histories.append(obj_value)
#     298 return histories
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras_tuner/engine/tuner.py:222, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     220 hp = trial.hyperparameters
#     221 model = self._try_build(hp)
# --> 222 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     223 tuner_utils.validate_trial_results(
#     224     results, self.oracle.objective, "HyperModel.fit()"
#     225 )
#     226 return results
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras_tuner/engine/hypermodel.py:140, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     116 def fit(self, hp, model, *args, **kwargs):
#     117     """Train the model.
#     118
#     119     Args:
#    (...)
#     138         If return a float, it should be the `objective` value.
#     139     """
# --> 140     return model.fit(*args, **kwargs)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2495, in Function.__call__(self, *args, **kwargs)
#    2492 """Calls a graph function specialized to the inputs."""
#    2493 with self._lock:
#    2494   (graph_function,
# -> 2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2738, in Function._maybe_define_function(self, args, kwargs)
#    2733 except TypeError as e:
#    2734   raise TypeError(
#    2735       "Arguments supplied to `defun`-generated functions must be hashable."
#    2736       ) from e
# -> 2738 graph_function = self._function_cache.lookup(func_cache_key, True)
#    2739 if graph_function is not None:
#    2740   return graph_function, filtered_flat_args
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_cache.py:224, in FunctionCache.lookup(self, key, use_function_subtyping)
#     222 dispatch_key = self._dispatch_table.dispatch(key)
#     223 if dispatch_key is not None:
# --> 224   return self._primary[dispatch_key]
#     226 return None
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_cache.py:187, in FunctionCacheKey.__eq__(self, other)
#     183 if not isinstance(other, FunctionCacheKey):
#     184   return False
#     186 return (self.call_context == other.call_context and
# --> 187         self.args_signature == other.args_signature and
#     188         self.captures_signature == other.captures_signature)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/core/function/trace_type/default_types.py:204, in Tuple.__eq__(self, other)
#     201 if not isinstance(other, Tuple):
#     202   return False
# --> 204 return self.components == other.components
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/core/function/trace_type/default_types.py:204, in Tuple.__eq__(self, other)
#     201 if not isinstance(other, Tuple):
#     202   return False
# --> 204 return self.components == other.components
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/core/function/trace_type/default_types.py:598, in Reference.__eq__(self, other)
#     593 if not isinstance(other, trace.TraceType):
#     594   return NotImplemented
#     596 return isinstance(
#     597     other, Reference
# --> 598 ) and self.identifier == other.identifier and self.base == other.base
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:476, in TypeSpec.__eq__(self, other)
#     473 def __eq__(self, other) -> bool:
#     474   # pylint: disable=protected-access
#     475   return (type(other) is type(self) and
# --> 476           self.__get_cmp_key() == other.__get_cmp_key())
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:531, in TypeSpec.__get_cmp_key(self)
#     529 """Returns a hashable eq-comparable key for `self`."""
#     530 # TODO(b/133606651): Decide whether to cache this value.
# --> 531 return (type(self), self.__make_cmp_key(self._serialize()))
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:549, in TypeSpec.__make_cmp_key(self, value)
#     543   return tuple([
#     544       tuple([self.__make_cmp_key(key),
#     545              self.__make_cmp_key(value[key])])
#     546       for key in sorted(value.keys())
#     547   ])
#     548 if isinstance(value, tuple):
# --> 549   return tuple([self.__make_cmp_key(v) for v in value])
#     550 if isinstance(value, list):
#     551   return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:549, in <listcomp>(.0)
#     543   return tuple([
#     544       tuple([self.__make_cmp_key(key),
#     545              self.__make_cmp_key(value[key])])
#     546       for key in sorted(value.keys())
#     547   ])
#     548 if isinstance(value, tuple):
# --> 549   return tuple([self.__make_cmp_key(v) for v in value])
#     550 if isinstance(value, list):
#     551   return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:549, in TypeSpec.__make_cmp_key(self, value)
#     543   return tuple([
#     544       tuple([self.__make_cmp_key(key),
#     545              self.__make_cmp_key(value[key])])
#     546       for key in sorted(value.keys())
#     547   ])
#     548 if isinstance(value, tuple):
# --> 549   return tuple([self.__make_cmp_key(v) for v in value])
#     550 if isinstance(value, list):
#     551   return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:549, in <listcomp>(.0)
#     543   return tuple([
#     544       tuple([self.__make_cmp_key(key),
#     545              self.__make_cmp_key(value[key])])
#     546       for key in sorted(value.keys())
#     547   ])
#     548 if isinstance(value, tuple):
# --> 549   return tuple([self.__make_cmp_key(v) for v in value])
#     550 if isinstance(value, list):
#     551   return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:535, in TypeSpec.__make_cmp_key(self, value)
#     533 def __make_cmp_key(self, value):
#     534   """Converts `value` to a hashable key."""
# --> 535   if isinstance(value, (int, float, bool, np.generic, dtypes.DType, TypeSpec,
#     536                         tensor_shape.TensorShape)):
#     537     return value
#     538   if isinstance(value, compat.bytes_or_text_types):
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %%
bm = tuner.get_best_models(num_models=1)[0]
y_hat = model.predict(X_test)
plt.scatter(y_hat.flatten(), y_test.to_numpy().flatten(), s=0.1)
plt.plot(np.linspace(0, 0.02), np.linspace(0, 0.02), linestyle=':', color='orange')
plt.xlabel('pred')
plt.ylabel('true')
# Out:
# 623/623 [==============================] - 1s 1ms/step
# Text(0, 0.5, 'true')

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in hyperparameters/eq
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7fd92698a6b0>
# Trial summary
# Hyperparameters:
# n_hidden: 4
# units: 128
# dropout: 0.09
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# tuner/trial_id: 0143
# Score: 0.0011498170206323266
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 96
# dropout: 0.07
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0238
# Score: 0.0012141329934820533
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 192
# dropout: 0.04
# loss: mse
# hidden_activation: relu
# output_activation: linear
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0219
# Score: 0.0015096659772098064
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 96
# dropout: 0.09
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0203
# Score: 0.001544067868962884
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 288
# dropout: 0.04
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# tuner/trial_id: 0145
# Score: 0.0016132242744788527
# Trial summary
# Hyperparameters:
# n_hidden: 4
# units: 128
# dropout: 0.09
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 4
# tuner/round: 3
# tuner/trial_id: 0134
# Score: 0.0016252239001914859
# Trial summary
# Hyperparameters:
# n_hidden: 4
# units: 224
# dropout: 0.14
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0207
# Score: 0.0016253396170213819
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 96
# dropout: 0.07
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 34
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.0017020456725731492
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 352
# dropout: 0.05
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0229
# Score: 0.0018521463498473167
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 256
# dropout: 0.08
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0236
# Score: 0.001852189190685749

# %%
model.save('models/det_sequence')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/det_sequence/assets
# INFO:tensorflow:Assets written to: models/det_sequence/assets
