# %%
import pandas as pd
import numpy as np
import math
import glob
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from multiprocessing import Pool
seed = 42

# %%
with Pool(50) as p:
    samples = pd.concat(p.map(pd.read_csv, glob.glob('./outputs/det/*.csv')))
samples = samples.reset_index(drop=True)

# %%
plt.scatter(samples.init_EIR, samples.EIR)
plt.plot(np.arange(100), np.arange(100), color='orange')

# %%
samples = samples.drop(samples[samples.EIR == -1].index).reset_index(drop=True)

# %%
output_columns = [f'prev_{i}' for i in range(1, 366)]
outputs = samples[output_columns]
features = samples.drop(output_columns + ['init_EIR'], 1)
n_features = len(features.columns)
n_outputs = len(outputs.columns)
# Out:
# /tmp/ipykernel_46089/3418533024.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   features = samples.drop(output_columns + ['init_EIR'], 1)

# %%
idx_train, idx_test = train_test_split(
    np.arange(len(outputs)), #np.arange(100000),
    test_size=0.2,
    random_state=seed
)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, layers
# Out:
# 2022-11-04 10:02:22.446903: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-04 10:02:22.983400: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
X_train = features.iloc[idx_train]
y_train = outputs.iloc[idx_train]
X_test = features.iloc[idx_test]
y_test = outputs.iloc[idx_test]

scaler = layers.Normalization()
scaler.adapt(X_train.to_numpy())
# Out:
# 2022-11-04 10:02:26.464206: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-04 10:02:34.671257: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22337 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:27:00.0, compute capability: 8.6
# 2022-11-04 10:02:34.696850: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22337 MB memory:  -> device: 1, name: NVIDIA RTX A5000, pci bus id: 0000:28:00.0, compute capability: 8.6
# 2022-11-04 10:02:34.716983: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 22337 MB memory:  -> device: 2, name: NVIDIA RTX A5000, pci bus id: 0000:43:00.0, compute capability: 8.6
# 2022-11-04 10:02:34.740847: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 22337 MB memory:  -> device: 3, name: NVIDIA RTX A5000, pci bus id: 0000:44:00.0, compute capability: 8.6
# 2022-11-04 10:02:34.760746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 22337 MB memory:  -> device: 4, name: NVIDIA RTX A5000, pci bus id: 0000:a3:00.0, compute capability: 8.6
# 2022-11-04 10:02:34.776714: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 22337 MB memory:  -> device: 5, name: NVIDIA RTX A5000, pci bus id: 0000:a4:00.0, compute capability: 8.6
# 2022-11-04 10:02:34.800774: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 22337 MB memory:  -> device: 6, name: NVIDIA RTX A5000, pci bus id: 0000:c3:00.0, compute capability: 8.6
# 2022-11-04 10:02:34.820894: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 22337 MB memory:  -> device: 7, name: NVIDIA RTX A5000, pci bus id: 0000:c4:00.0, compute capability: 8.6

# %%
def create_model(
    optimiser='adam',
    n_hidden=3,
    units=512,
    dropout=.1,
    loss='mse',
    hidden_activation='relu',
    hidden_initialiser='he_normal',
    output_activation='linear',
    output_initialiser='glorot_normal'
):
    model = Sequential()
    model.add(layers.Input(shape=(n_features,), dtype='float32'))
    model.add(scaler)
    for i in range(n_hidden):
        model.add(layers.Dense(
            units,
            activation=hidden_activation,
            kernel_initializer=hidden_initialiser)
        )
        model.add(layers.Dropout(dropout))
    model.add(layers.Dense(n_outputs, activation=output_activation, kernel_initializer=output_initialiser))
    model.compile(loss=loss, optimizer=optimiser, metrics='mse')
    return model

# %%
model = create_model()
model.fit(X_train, y_train, batch_size=100, epochs=100)
# Out:
# Epoch 1/100
#  19/227 [=>............................] - ETA: 1s - loss: 0.2371 - mse: 0.2371
# 2022-11-04 10:02:39.441404: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 227/227 [==============================] - 3s 5ms/step - loss: 0.0313 - mse: 0.0313
# Epoch 2/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0067 - mse: 0.0067
# Epoch 3/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0057 - mse: 0.0057
# Epoch 4/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0052 - mse: 0.0052
# Epoch 5/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0049 - mse: 0.0049
# Epoch 6/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0047 - mse: 0.0047
# Epoch 7/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0045 - mse: 0.0045
# Epoch 8/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0042 - mse: 0.0042
# Epoch 9/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0040 - mse: 0.0040
# Epoch 10/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0039 - mse: 0.0039
# Epoch 11/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0038 - mse: 0.0038
# Epoch 12/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0037 - mse: 0.0037
# Epoch 13/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 14/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 15/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 16/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 17/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 18/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 19/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 20/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 21/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 22/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 23/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 24/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0029 - mse: 0.0029
# Epoch 25/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0029 - mse: 0.0029
# Epoch 26/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 27/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 28/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 29/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 30/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 31/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0026 - mse: 0.0026
# Epoch 32/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0026 - mse: 0.0026
# Epoch 33/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 34/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 35/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 36/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 37/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 38/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 39/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 40/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 41/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 42/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 43/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 44/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 45/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 46/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 47/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 48/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 49/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 50/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 51/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 52/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 53/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 54/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 55/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 56/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 57/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 58/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 59/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 60/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 61/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 62/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 63/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 64/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 65/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 66/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 67/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 68/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 69/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 70/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 71/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 72/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 73/100
# 227/227 [==============================] - 2s 7ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 74/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 75/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 76/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 77/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 78/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 79/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 80/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 81/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 82/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 83/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 84/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 85/100
# 227/227 [==============================] - 2s 8ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 86/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 87/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 88/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 89/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 90/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 91/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 92/100
# 227/227 [==============================] - 2s 7ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 93/100
# 227/227 [==============================] - 2s 7ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 94/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 95/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 96/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 97/100
# 227/227 [==============================] - 1s 4ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 98/100
# 227/227 [==============================] - 1s 6ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 99/100
# 227/227 [==============================] - 1s 5ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 100/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.0012 - mse: 0.0012

# %%
from tensorflow.keras.models import load_model

# %%
base_model = load_model('./models/eq/')

# %%
pre_f = np.concatenate([np.array([30]), np.arange(20)])
post_f = np.array([20, 21, 22])

# %%
def create_model_from_base(
    base_model,
    optimiser='adam',
    n_hidden=1,
    units=512,
    dropout=.0,
    loss='log_cosh',
    hidden_activation='relu',
    hidden_initialiser='he_normal',
    output_activation='linear',
    output_initialiser='glorot_normal'
):
    input_layer = layers.Input(shape=(n_features,), dtype='float32')
    base_input = tf.concat(
        [
            tf.gather(input_layer, indices=pre_f, axis=1),
            tf.constant(.3, shape=(1,1)), #f to broadcast
            tf.gather(input_layer, indices=post_f, axis=1)
        ],
        1
    )
    
    base_representation = base_input
    for base_layer in base_model.layers[:-1]:
        base_layer.trainable = False
        base_representation = base_layer(base_representation)

    input_layer = scaler(input_layer)
    tf.concat([input_layer, base_representation], 1)
    for i in range(n_hidden):
        model.add(layers.Dense(
            units,
            activation=hidden_activation,
            kernel_initializer=hidden_initialiser)
        )
        model.add(layers.Dropout(dropout))
    model.add(layers.Dense(n_outputs, activation=output_activation, kernel_initializer=output_initialiser))
    model.compile(loss=loss, optimizer=optimiser, metrics='mse')
    return model

# %%
model = create_model_from_base(base_model)
model.fit(X_train, y_train, batch_size=100, epochs=100)
# Out:
# Epoch 1/100
# 227/227 [==============================] - 2s 6ms/step - loss: 0.0015 - mse: 0.0031
# Epoch 2/100
# 227/227 [==============================] - 1s 6ms/step - loss: 6.1685e-04 - mse: 0.0012
# Epoch 3/100
# 227/227 [==============================] - 2s 7ms/step - loss: 6.0731e-04 - mse: 0.0012
# Epoch 4/100
# 227/227 [==============================] - 1s 6ms/step - loss: 6.0321e-04 - mse: 0.0012
# Epoch 5/100
# 227/227 [==============================] - 1s 6ms/step - loss: 5.8777e-04 - mse: 0.0012
# Epoch 6/100
# 227/227 [==============================] - 1s 5ms/step - loss: 5.6175e-04 - mse: 0.0011
# Epoch 7/100
# 227/227 [==============================] - 2s 8ms/step - loss: 5.2588e-04 - mse: 0.0011
# Epoch 8/100
# 227/227 [==============================] - 1s 6ms/step - loss: 5.0317e-04 - mse: 0.0010
# Epoch 9/100
# 227/227 [==============================] - 1s 6ms/step - loss: 4.6138e-04 - mse: 9.2373e-04
# Epoch 10/100
# 227/227 [==============================] - 1s 6ms/step - loss: 4.4984e-04 - mse: 9.0058e-04
# Epoch 11/100
# 227/227 [==============================] - 1s 5ms/step - loss: 4.3778e-04 - mse: 8.7646e-04
# Epoch 12/100
# 227/227 [==============================] - 1s 3ms/step - loss: 4.3558e-04 - mse: 8.7197e-04
# Epoch 13/100
# 227/227 [==============================] - 1s 3ms/step - loss: 4.2326e-04 - mse: 8.4731e-04
# Epoch 14/100
# 227/227 [==============================] - 2s 8ms/step - loss: 4.2893e-04 - mse: 8.5865e-04
# Epoch 15/100
# 227/227 [==============================] - 1s 6ms/step - loss: 4.1828e-04 - mse: 8.3730e-04
# Epoch 16/100
# 227/227 [==============================] - 1s 3ms/step - loss: 4.0323e-04 - mse: 8.0718e-04
# Epoch 17/100
# 227/227 [==============================] - 1s 5ms/step - loss: 4.0092e-04 - mse: 8.0254e-04
# Epoch 18/100
# 227/227 [==============================] - 1s 6ms/step - loss: 4.0038e-04 - mse: 8.0150e-04
# Epoch 19/100
# 227/227 [==============================] - 1s 5ms/step - loss: 3.9619e-04 - mse: 7.9304e-04
# Epoch 20/100
# 227/227 [==============================] - 1s 5ms/step - loss: 3.8797e-04 - mse: 7.7658e-04
# Epoch 21/100
# 227/227 [==============================] - 1s 4ms/step - loss: 3.8818e-04 - mse: 7.7711e-04
# Epoch 22/100
# 227/227 [==============================] - 1s 4ms/step - loss: 3.7849e-04 - mse: 7.5765e-04
# Epoch 23/100
# 227/227 [==============================] - 1s 3ms/step - loss: 3.6742e-04 - mse: 7.3541e-04
# Epoch 24/100
# 227/227 [==============================] - 1s 3ms/step - loss: 3.6939e-04 - mse: 7.3936e-04
# Epoch 25/100
# 227/227 [==============================] - 1s 4ms/step - loss: 3.5202e-04 - mse: 7.0456e-04
# Epoch 26/100
# 227/227 [==============================] - 1s 5ms/step - loss: 3.5349e-04 - mse: 7.0754e-04
# Epoch 27/100
# 227/227 [==============================] - 1s 5ms/step - loss: 3.5107e-04 - mse: 7.0269e-04
# Epoch 28/100
# 227/227 [==============================] - 1s 5ms/step - loss: 3.4294e-04 - mse: 6.8640e-04
# Epoch 29/100
# 227/227 [==============================] - 1s 5ms/step - loss: 3.2757e-04 - mse: 6.5559e-04
# Epoch 30/100
# 227/227 [==============================] - 1s 7ms/step - loss: 3.2161e-04 - mse: 6.4366e-04
# Epoch 31/100
# 227/227 [==============================] - 1s 6ms/step - loss: 3.1782e-04 - mse: 6.3607e-04
# Epoch 32/100
# 227/227 [==============================] - 1s 5ms/step - loss: 3.0741e-04 - mse: 6.1523e-04
# Epoch 33/100
# 227/227 [==============================] - 1s 4ms/step - loss: 3.0535e-04 - mse: 6.1110e-04
# Epoch 34/100
# 227/227 [==============================] - 1s 5ms/step - loss: 3.0147e-04 - mse: 6.0332e-04
# Epoch 35/100
# 227/227 [==============================] - 1s 4ms/step - loss: 2.9585e-04 - mse: 5.9209e-04
# Epoch 36/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.9122e-04 - mse: 5.8280e-04
# Epoch 37/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.9115e-04 - mse: 5.8267e-04
# Epoch 38/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.8745e-04 - mse: 5.7526e-04
# Epoch 39/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.8540e-04 - mse: 5.7118e-04
# Epoch 40/100
# 227/227 [==============================] - 1s 4ms/step - loss: 2.8053e-04 - mse: 5.6144e-04
# Epoch 41/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.7988e-04 - mse: 5.6009e-04
# Epoch 42/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.8610e-04 - mse: 5.7259e-04
# Epoch 43/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.7203e-04 - mse: 5.4438e-04
# Epoch 44/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.6876e-04 - mse: 5.3783e-04
# Epoch 45/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.7587e-04 - mse: 5.5208e-04
# Epoch 46/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.6566e-04 - mse: 5.3163e-04
# Epoch 47/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.6804e-04 - mse: 5.3639e-04
# Epoch 48/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.5947e-04 - mse: 5.1922e-04
# Epoch 49/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.6246e-04 - mse: 5.2522e-04
# Epoch 50/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.5844e-04 - mse: 5.1717e-04
# Epoch 51/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.5903e-04 - mse: 5.1834e-04
# Epoch 52/100
# 227/227 [==============================] - 2s 7ms/step - loss: 2.5771e-04 - mse: 5.1571e-04
# Epoch 53/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.5418e-04 - mse: 5.0863e-04
# Epoch 54/100
# 227/227 [==============================] - 1s 4ms/step - loss: 2.5246e-04 - mse: 5.0520e-04
# Epoch 55/100
# 227/227 [==============================] - 2s 7ms/step - loss: 2.5425e-04 - mse: 5.0879e-04
# Epoch 56/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.5353e-04 - mse: 5.0744e-04
# Epoch 57/100
# 227/227 [==============================] - 2s 7ms/step - loss: 2.4853e-04 - mse: 4.9733e-04
# Epoch 58/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.4882e-04 - mse: 4.9796e-04
# Epoch 59/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.4545e-04 - mse: 4.9116e-04
# Epoch 60/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.4633e-04 - mse: 4.9293e-04
# Epoch 61/100
# 227/227 [==============================] - 2s 7ms/step - loss: 2.4822e-04 - mse: 4.9671e-04
# Epoch 62/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.4728e-04 - mse: 4.9485e-04
# Epoch 63/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.3902e-04 - mse: 4.7829e-04
# Epoch 64/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.4334e-04 - mse: 4.8694e-04
# Epoch 65/100
# 227/227 [==============================] - 1s 7ms/step - loss: 2.3971e-04 - mse: 4.7967e-04
# Epoch 66/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.3689e-04 - mse: 4.7403e-04
# Epoch 67/100
# 227/227 [==============================] - 2s 7ms/step - loss: 2.3736e-04 - mse: 4.7495e-04
# Epoch 68/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.3193e-04 - mse: 4.6409e-04
# Epoch 69/100
# 227/227 [==============================] - 2s 7ms/step - loss: 2.3094e-04 - mse: 4.6211e-04
# Epoch 70/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.3269e-04 - mse: 4.6562e-04
# Epoch 71/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.2554e-04 - mse: 4.5130e-04
# Epoch 72/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.2731e-04 - mse: 4.5483e-04
# Epoch 73/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.3030e-04 - mse: 4.6083e-04
# Epoch 74/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.2870e-04 - mse: 4.5763e-04
# Epoch 75/100
# 227/227 [==============================] - 2s 7ms/step - loss: 2.2642e-04 - mse: 4.5306e-04
# Epoch 76/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.2622e-04 - mse: 4.5266e-04
# Epoch 77/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.3212e-04 - mse: 4.6448e-04
# Epoch 78/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.2882e-04 - mse: 4.5788e-04
# Epoch 79/100
# 227/227 [==============================] - 2s 7ms/step - loss: 2.2529e-04 - mse: 4.5081e-04
# Epoch 80/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.2941e-04 - mse: 4.5904e-04
# Epoch 81/100
# 227/227 [==============================] - 2s 7ms/step - loss: 2.2160e-04 - mse: 4.4340e-04
# Epoch 82/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.1742e-04 - mse: 4.3503e-04
# Epoch 83/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.2373e-04 - mse: 4.4768e-04
# Epoch 84/100
# 227/227 [==============================] - 2s 7ms/step - loss: 2.1650e-04 - mse: 4.3320e-04
# Epoch 85/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.2231e-04 - mse: 4.4483e-04
# Epoch 86/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.1439e-04 - mse: 4.2896e-04
# Epoch 87/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.2112e-04 - mse: 4.4244e-04
# Epoch 88/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.1619e-04 - mse: 4.3258e-04
# Epoch 89/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.1502e-04 - mse: 4.3023e-04
# Epoch 90/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.1784e-04 - mse: 4.3589e-04
# Epoch 91/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.1468e-04 - mse: 4.2956e-04
# Epoch 92/100
# 227/227 [==============================] - 1s 4ms/step - loss: 2.0929e-04 - mse: 4.1876e-04
# Epoch 93/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.0676e-04 - mse: 4.1368e-04
# Epoch 94/100
# 227/227 [==============================] - 1s 5ms/step - loss: 2.1156e-04 - mse: 4.2331e-04
# Epoch 95/100
# 227/227 [==============================] - 2s 7ms/step - loss: 2.0802e-04 - mse: 4.1622e-04
# Epoch 96/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.0919e-04 - mse: 4.1856e-04
# Epoch 97/100
# 227/227 [==============================] - 1s 4ms/step - loss: 2.0462e-04 - mse: 4.0941e-04
# Epoch 98/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.0340e-04 - mse: 4.0697e-04
# Epoch 99/100
# 227/227 [==============================] - 1s 6ms/step - loss: 2.0876e-04 - mse: 4.1773e-04
# Epoch 100/100
# 227/227 [==============================] - 2s 7ms/step - loss: 2.1082e-04 - mse: 4.2183e-04

# %%
y_hat = model.predict(X_test)
# Out:
# 178/178 [==============================] - 1s 3ms/step

# %%
plt.scatter(y_hat.flatten(), y_test.to_numpy().flatten(), s=0.1)
plt.plot(np.linspace(0, 0.9), np.linspace(0, 0.9), linestyle=':', color='orange')
plt.xlabel('pred')
plt.ylabel('true')
# Out:
# Text(0, 0.5, 'true')

# %%
plt.scatter(np.mean(y_hat, axis=1), np.mean(y_test, axis=1), s=0.1)
plt.plot(np.linspace(0, 0.9), np.linspace(0, 0.9), linestyle=':', color='orange')
plt.xlabel('pred')
plt.ylabel('true')
# Out:
# Text(0, 0.5, 'true')

# %%
plt.plot(y_hat[3])
plt.plot(y_test.to_numpy()[3])

# %%
y_test[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/projects/eqio/env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 y_test[0]
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/pandas/core/frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 0

# %%
import keras_tuner as kt

# %%
def bulid_hypermodel(hp):
    return create_model(
        n_hidden = hp.Int("n_hidden", min_value=1, max_value=5, step=1),
        units = hp.Int("units", min_value=32, max_value=512, step=32),
        dropout = hp.Float("dropout", min_value=0., max_value=.2, step=.01),
        loss = hp.Choice("loss", ['mse', 'log_cosh']),
        hidden_activation = hp.Choice("hidden_activation", ['relu', 'elu']),
        output_activation = hp.Choice("output_activation", ['linear', 'softmax'])
    )

# %%
tuner = kt.Hyperband(
    hypermodel=bulid_hypermodel,
    objective="val_mse",
    max_epochs=100,
    seed=42,
    overwrite=True,
    directory="hyperparameters",
    project_name="det",
)

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 6
# n_hidden (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 5, 'step': 1, 'sampling': None}
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# dropout (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.2, 'step': 0.01, 'sampling': None}
# loss (Choice)
# {'default': 'mse', 'conditions': [], 'values': ['mse', 'log_cosh'], 'ordered': False}
# hidden_activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'elu'], 'ordered': False}
# output_activation (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'softmax'], 'ordered': False}

# %%
X_hyp_train, X_hyp_val, y_hyp_train, y_hyp_val = train_test_split(
    X_train,
    y_train,
    test_size=0.2,
    random_state=seed
)

# %%
tuner.search(
    X_hyp_train,
    y_hyp_train,
    validation_data=(X_hyp_val, y_hyp_val),
    callbacks=[tf.keras.callbacks.EarlyStopping("mse", min_delta=1e-10, patience=5)]
)
# Out:
# Trial 230 Complete [00h 02m 17s]
# val_mse: 0.00022005359642207623
#
# Best val_mse So Far: 9.33476330828853e-05
# Total elapsed time: 02h 25m 44s
#
# Search: Running Trial #231
#
# Value             |Best Value So Far |Hyperparameter
# 4                 |4                 |n_hidden
# 192               |96                |units
# 0.02              |0                 |dropout
# mse               |mse               |loss
# elu               |elu               |hidden_activation
# linear            |linear            |output_activation
# 34                |100               |tuner/epochs
# 12                |34                |tuner/initial_epoch
# 2                 |4                 |tuner/bracket
# 1                 |4                 |tuner/round
# 0225              |0144              |tuner/trial_id
#
# Epoch 13/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 14/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 15/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 9.4117e-04 - val_mse: 9.4117e-04
# Epoch 16/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 6.9665e-04 - val_mse: 6.9665e-04
# Epoch 17/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 6.0813e-04 - val_mse: 6.0813e-04
# Epoch 18/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 9.1305e-04 - mse: 9.1305e-04 - val_loss: 5.7177e-04 - val_mse: 5.7177e-04
# Epoch 19/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 8.1329e-04 - mse: 8.1329e-04 - val_loss: 5.4775e-04 - val_mse: 5.4775e-04
# Epoch 20/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 7.4924e-04 - mse: 7.4924e-04 - val_loss: 5.9009e-04 - val_mse: 5.9009e-04
# Epoch 21/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 7.0331e-04 - mse: 7.0331e-04 - val_loss: 3.6985e-04 - val_mse: 3.6985e-04
# Epoch 22/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 6.5834e-04 - mse: 6.5834e-04 - val_loss: 3.8562e-04 - val_mse: 3.8562e-04
# Epoch 23/34
# 2000/2000 [==============================] - 7s 3ms/step - loss: 6.0862e-04 - mse: 6.0862e-04 - val_loss: 4.3958e-04 - val_mse: 4.3958e-04
# Epoch 24/34
#  804/2000 [===========>..................] - ETA: 3s - loss: 5.8519e-04 - mse: 5.8519e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 tuner.search(
#       2     X_hyp_train,
#       3     y_hyp_train,
#       4     validation_data=(X_hyp_val, y_hyp_val),
#       5     callbacks=[tf.keras.callbacks.EarlyStopping("mse", min_delta=1e-10, patience=5)]
#       6 )
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras_tuner/engine/base_tuner.py:183, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     180     continue
#     182 self.on_trial_begin(trial)
# --> 183 results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     184 # `results` is None indicates user updated oracle in `run_trial()`.
#     185 if results is None:
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras_tuner/tuners/hyperband.py:384, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     382     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     383     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 384 return super(Hyperband, self).run_trial(trial, *fit_args, **fit_kwargs)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras_tuner/engine/tuner.py:295, in Tuner.run_trial(self, trial, *args, **kwargs)
#     293     callbacks.append(model_checkpoint)
#     294     copied_kwargs["callbacks"] = callbacks
# --> 295     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     297     histories.append(obj_value)
#     298 return histories
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras_tuner/engine/tuner.py:222, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     220 hp = trial.hyperparameters
#     221 model = self._try_build(hp)
# --> 222 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     223 tuner_utils.validate_trial_results(
#     224     results, self.oracle.objective, "HyperModel.fit()"
#     225 )
#     226 return results
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras_tuner/engine/hypermodel.py:140, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     116 def fit(self, hp, model, *args, **kwargs):
#     117     """Train the model.
#     118
#     119     Args:
#    (...)
#     138         If return a float, it should be the `objective` value.
#     139     """
# --> 140     return model.fit(*args, **kwargs)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2495, in Function.__call__(self, *args, **kwargs)
#    2492 """Calls a graph function specialized to the inputs."""
#    2493 with self._lock:
#    2494   (graph_function,
# -> 2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2738, in Function._maybe_define_function(self, args, kwargs)
#    2733 except TypeError as e:
#    2734   raise TypeError(
#    2735       "Arguments supplied to `defun`-generated functions must be hashable."
#    2736       ) from e
# -> 2738 graph_function = self._function_cache.lookup(func_cache_key, True)
#    2739 if graph_function is not None:
#    2740   return graph_function, filtered_flat_args
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_cache.py:224, in FunctionCache.lookup(self, key, use_function_subtyping)
#     222 dispatch_key = self._dispatch_table.dispatch(key)
#     223 if dispatch_key is not None:
# --> 224   return self._primary[dispatch_key]
#     226 return None
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_cache.py:187, in FunctionCacheKey.__eq__(self, other)
#     183 if not isinstance(other, FunctionCacheKey):
#     184   return False
#     186 return (self.call_context == other.call_context and
# --> 187         self.args_signature == other.args_signature and
#     188         self.captures_signature == other.captures_signature)
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/core/function/trace_type/default_types.py:204, in Tuple.__eq__(self, other)
#     201 if not isinstance(other, Tuple):
#     202   return False
# --> 204 return self.components == other.components
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/core/function/trace_type/default_types.py:204, in Tuple.__eq__(self, other)
#     201 if not isinstance(other, Tuple):
#     202   return False
# --> 204 return self.components == other.components
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/core/function/trace_type/default_types.py:598, in Reference.__eq__(self, other)
#     593 if not isinstance(other, trace.TraceType):
#     594   return NotImplemented
#     596 return isinstance(
#     597     other, Reference
# --> 598 ) and self.identifier == other.identifier and self.base == other.base
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:476, in TypeSpec.__eq__(self, other)
#     473 def __eq__(self, other) -> bool:
#     474   # pylint: disable=protected-access
#     475   return (type(other) is type(self) and
# --> 476           self.__get_cmp_key() == other.__get_cmp_key())
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:531, in TypeSpec.__get_cmp_key(self)
#     529 """Returns a hashable eq-comparable key for `self`."""
#     530 # TODO(b/133606651): Decide whether to cache this value.
# --> 531 return (type(self), self.__make_cmp_key(self._serialize()))
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:549, in TypeSpec.__make_cmp_key(self, value)
#     543   return tuple([
#     544       tuple([self.__make_cmp_key(key),
#     545              self.__make_cmp_key(value[key])])
#     546       for key in sorted(value.keys())
#     547   ])
#     548 if isinstance(value, tuple):
# --> 549   return tuple([self.__make_cmp_key(v) for v in value])
#     550 if isinstance(value, list):
#     551   return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:549, in <listcomp>(.0)
#     543   return tuple([
#     544       tuple([self.__make_cmp_key(key),
#     545              self.__make_cmp_key(value[key])])
#     546       for key in sorted(value.keys())
#     547   ])
#     548 if isinstance(value, tuple):
# --> 549   return tuple([self.__make_cmp_key(v) for v in value])
#     550 if isinstance(value, list):
#     551   return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:549, in TypeSpec.__make_cmp_key(self, value)
#     543   return tuple([
#     544       tuple([self.__make_cmp_key(key),
#     545              self.__make_cmp_key(value[key])])
#     546       for key in sorted(value.keys())
#     547   ])
#     548 if isinstance(value, tuple):
# --> 549   return tuple([self.__make_cmp_key(v) for v in value])
#     550 if isinstance(value, list):
#     551   return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:549, in <listcomp>(.0)
#     543   return tuple([
#     544       tuple([self.__make_cmp_key(key),
#     545              self.__make_cmp_key(value[key])])
#     546       for key in sorted(value.keys())
#     547   ])
#     548 if isinstance(value, tuple):
# --> 549   return tuple([self.__make_cmp_key(v) for v in value])
#     550 if isinstance(value, list):
#     551   return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# File ~/projects/eqio/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:535, in TypeSpec.__make_cmp_key(self, value)
#     533 def __make_cmp_key(self, value):
#     534   """Converts `value` to a hashable key."""
# --> 535   if isinstance(value, (int, float, bool, np.generic, dtypes.DType, TypeSpec,
#     536                         tensor_shape.TensorShape)):
#     537     return value
#     538   if isinstance(value, compat.bytes_or_text_types):
#
# File ~/.pyenv/versions/3.10.7/lib/python3.10/abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %%
bm = tuner.get_best_models(num_models=1)[0]
y_hat = model.predict(X_test)
plt.scatter(y_hat.flatten(), y_test.to_numpy().flatten(), s=0.1)
plt.plot(np.linspace(0, 0.02), np.linspace(0, 0.02), linestyle=':', color='orange')
plt.xlabel('pred')
plt.ylabel('true')
# Out:
# 623/623 [==============================] - 1s 1ms/step
# Text(0, 0.5, 'true')

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in hyperparameters/eq
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7fd92698a6b0>
# Trial summary
# Hyperparameters:
# n_hidden: 4
# units: 128
# dropout: 0.09
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# tuner/trial_id: 0143
# Score: 0.0011498170206323266
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 96
# dropout: 0.07
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0238
# Score: 0.0012141329934820533
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 192
# dropout: 0.04
# loss: mse
# hidden_activation: relu
# output_activation: linear
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0219
# Score: 0.0015096659772098064
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 96
# dropout: 0.09
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0203
# Score: 0.001544067868962884
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 288
# dropout: 0.04
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 4
# tuner/round: 4
# tuner/trial_id: 0145
# Score: 0.0016132242744788527
# Trial summary
# Hyperparameters:
# n_hidden: 4
# units: 128
# dropout: 0.09
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 34
# tuner/initial_epoch: 12
# tuner/bracket: 4
# tuner/round: 3
# tuner/trial_id: 0134
# Score: 0.0016252239001914859
# Trial summary
# Hyperparameters:
# n_hidden: 4
# units: 224
# dropout: 0.14
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 0207
# Score: 0.0016253396170213819
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 96
# dropout: 0.07
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 34
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.0017020456725731492
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 352
# dropout: 0.05
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0229
# Score: 0.0018521463498473167
# Trial summary
# Hyperparameters:
# n_hidden: 3
# units: 256
# dropout: 0.08
# loss: log_cosh
# hidden_activation: elu
# output_activation: linear
# tuner/epochs: 100
# tuner/initial_epoch: 34
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0236
# Score: 0.001852189190685749

# %%
model.save('models/det')
# Out:
# INFO:tensorflow:Assets written to: models/det/assets
